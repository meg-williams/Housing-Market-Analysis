# %%
from re import VERBOSE
import pandas as pd

# maths and plots
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import category_encoders as ce
import xgboost as xgb
import dill as pickle 

# sklearn
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import root_mean_squared_error, mean_squared_error
from functions import *

import tensorflow as tf
from keras.models import Sequential, load_model
from keras.layers import Dense, Input

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_info_columns', 200)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# #### load_data

# %%
df = load_data('test.csv')

# %% [markdown]
# #### clean_data

# %%
clean_data(df)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave  Grvl      Reg
# 1     1462          20       RH         81.0    14267   Pave  Grvl      IR1
# 2     1463          60       RH         74.0    13830   Pave  Grvl      IR1
# 3     1464          60       RH         78.0     9978   Pave  Grvl      IR1
# 4     1465         120       RH         43.0     5005   Pave  Grvl      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RH         21.0     1936   Pave  Grvl      Reg
# 1455  2916         160       RH         21.0     1894   Pave  Grvl      Reg
# 1456  2917          20       RH        160.0    20000   Pave  Grvl      Reg
# 1457  2918          85       RH         62.0    10441   Pave  Grvl      Reg
# 1458  2919          60       RH         74.0     9627   Pave  Grvl      Reg
#
# ...

# %% [markdown]
# #### encode_data

# %%
df = encode_data(df, 'test', None)

# %% [markdown]
# #### ann

# %%
X = df.drop(columns=['Id'])

# %%
model_load = load_model('keras_model.keras')

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 122 columns):
#  #    Column                 Non-Null Count  Dtype
# ---   ------                 --------------  -----
#  0    MSSubClass             1459 non-null   int64
#  1    LotFrontage            1459 non-null   float64
#  2    LotArea                1459 non-null   int64
#  3    LandSlope              1459 non-null   int64
#  4    Neighborhood           1459 non-null   float64
#  5    Condition1             1459 non-null   float64
#  6    Condition2             1459 non-null   float64
#  7    HouseStyle             1459 non-null   float64
#  8    OverallQual            1459 non-null   int64
#  9    OverallCond            1459 non-null   int64
#  10   YearBuilt              1459 non-null   int64
#  11   YearRemodAdd           1459 non-null   int64
#  12   RoofMatl               1459 non-null   float64
#  13   Exterior1st            1459 non-null   float64
# ...

# %%
preds = model_load.predict(X)
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
preds
# Out:
# array([[121639.17],
#        [130271.72],
#        [205775.45],
#        ...,
#        [189766.17],
#        [122746.65],
#        [177254.3 ]], dtype=float32)

# %%
predictions_df = pd.DataFrame()
predictions_df.insert(0, 'Id', df['Id'])
predictions_df.insert(1, 'SalePrice', preds)
predictions_df.to_csv('ann1.csv', index=False)
