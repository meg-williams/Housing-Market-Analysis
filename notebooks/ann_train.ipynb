# %%
from re import VERBOSE
import pandas as pd

# maths and plots
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import category_encoders as ce
import xgboost as xgb
import dill as pickle 

# sklearn
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import root_mean_squared_error, mean_squared_error
from functions import *

import tensorflow as tf
from keras.models import Sequential, load_model 
from keras.layers import Dense, Input

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_info_columns', 200)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# #### load_data

# %%
df = load_data('train.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# #### clean_data

# %%
clean_data(df)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave  Grvl      Reg
# 1        2          20       RL         80.0     9600   Pave  Grvl      Reg
# 2        3          60       RL         68.0    11250   Pave  Grvl      IR1
# 3        4          70       RL         60.0     9550   Pave  Grvl      IR1
# 4        5          60       RL         84.0    14260   Pave  Grvl      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave  Grvl      Reg
# 1456  1457          20       RL         85.0    13175   Pave  Grvl      Reg
# 1457  1458          70       RL         66.0     9042   Pave  Grvl      Reg
# 1458  1459          20       RL         68.0     9717   Pave  Grvl      Reg
# 1459  1460          20       RL         75.0     9937   Pave  Grvl      Reg
#
# ...

# %% [markdown]
# #### encode_data

# %% [markdown]
# ##### df, data_type, target_co

# %%
df = encode_data(df, 'train', df['SalePrice'])

# %% [markdown]
# #### split_data

# %%
xtrain, xtest, ytrain, ytest = split_data(df.drop(columns=['Id', 'SalePrice']), df['SalePrice'])

# %% [markdown]
# #### ann model1

# %% [markdown]
# ##### (X,  y,  model,  layers,  width,  activation,  output,  output_activation,  learning_rate,  loss,  metrics,
# #####  epochs, batch_size, validation_split)

# %%
model1 = ann(xtrain, ytrain, Sequential(), 4, 500, 'relu', 1, 'linear', 
                     0.001, 'mse', ['mse', 'mae'], 200, 128, 0.3333)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 500)            │        61,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 500)            │       250,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 500)            │       250,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 500)            │       250,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │           501 │
# ...

# %%
preds = model1.predict(xtest)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
mse1 = mean_squared_error(preds, ytest)

# %%
mse1 = root_mean_squared_error(preds, ytest)

# %%
model1.save('keras_model.keras', overwrite=True, include_optimizer=True, save_format=None)
